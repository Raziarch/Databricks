# %% [markdown]
# ### using calendar data as ground truth
# * pull all data for recommendations
# * label data based on combination of theater and market segment
# * tie to recs data to obtain frame for all data and distribution of clusters
# * calculate most freq recommended products based on clusters label
# * create lookup table with clusters label and top recommendations
# * recommend most freq recommendation grouped by clusters

# %%
# %pip install /dbfs/FileStore/jars/82a8f80e_8266_43fb_be3c_12ac7a64dc2d/maas_utils-0.2.0-py3-none-any.whl
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Processing /dbfs/FileStore/jars/82a8f80e_8266_43fb_be3c_12ac7a64dc2d/maas_utils-0.2.0-py3-none-any.whl
# Installing collected packages: maas-utils
# Successfully installed maas-utils-0.2.0
# Python interpreter will be restarted.
# </div>

# %%
from mass_utils import pyspark_helpers as pysh
from mass_utils import databricks_helpers as dbh
from pyspark.sql.window import Window
import pyspark.sql.functions as F
import pandas as pd  
pd.set_option('display.max_rows', None)
from mass_utils import pandas_helpers as ph
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.mllib.evaluation import BinaryClassificationMetrics
from pyspark.mllib.util import MLUtils
from pyspark.sql.types import StringType,BooleanType,DateType
from pyspark.sql.functions import rand
import hyperopt
import numpy as np
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from sklearn.preprocessing import OneHotEncoder 
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stmt = """
with 
all_accts as (
SELECT ACCOUNT_ID from EXP_MKTG.DEV_DATA_SCIENCE.RAW_RECS_NEW
union
SELECT ACCOUNT_ID from EXP_MKTG.DATA_SCIENCE.RECOMMENDER_BASE_NEW
union
select ACCOUNT_ID from EXP_MKTG.DATA_SCIENCE.prospects_and_legacy_calendar_dataset
union
select ACCOUNT_ID from EXP_MKTG.DATA_SCIENCE.calendar_dataset
), 
acct_data as(
select a.ID,coalesce(MARKET_SEGMENT_C, 'Unknown') as MARKET_SEGMENT, CASE WHEN coalesce(INDUSTRY_GROUPING_C, 'UNK') = 'None'
                                                                                then 'UNK'
                                                                                else coalesce(INDUSTRY_GROUPING_C, 'UNK')
                                                                                    end as INDUSTRY_GROUPING,
                                                                      CASE WHEN terr.THEATER_2_C = 'APAC' THEN 'APCJ'
                                                                           WHEN terr.THEATER_2_C  = 'EMEA' THEN 'EMEA'
                                                                           WHEN terr.sub_theater_c = 'LATAM' THEN 'LATAM'
                                                                           WHEN terr.sub_theater_c = 'SP' THEN 'NA'
                                                                           WHEN terr.sub_theater_c = 'NA' THEN 'NA'
                                                                           ELSE 'Unknown'
                                                                           END theater
from prd_ent_raw.salesforce.account a left join prd_ent_raw.salesforce.territory_f_5_c terr on a.etm_territory_code_c = terr.territory_code_c
        and terr.is_deleted = false
        and terr.status_c='Active'
), 
joined_accts as(
select * from all_accts 
  left join acct_data on acct_data.ID = all_accts.ACCOUNT_ID
)
select ID, THEATER,MARKET_SEGMENT,INDUSTRY_GROUPING from joined_accts
"""

stmt_recs = """ SELECT * from EXP_MKTG.DEV_DATA_SCIENCE.POST_PROCESSED_RECS_NEW """
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
base_df = dbh.read_ede_data(stmt)
base_df = pysh.safe_name(base_df)
base_recs = dbh.read_ede_data(stmt_recs)
base_recs = pysh.safe_name(base_recs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
base_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>theater</th><th>market_segment</th><th>industry_grouping</th></tr></thead><tbody><tr><td>0015000000MdVGlAAN</td><td>NA</td><td>Large Enterprise</td><td>Retail</td></tr><tr><td>0015000000Mdb66AAB</td><td>LATAM</td><td>Government</td><td>Government</td></tr><tr><td>0015000000MdiEyAAJ</td><td>NA</td><td>Government</td><td>Government</td></tr><tr><td>0015000000MxPEtAAN</td><td>NA</td><td>Large Enterprise</td><td>Technology</td></tr><tr><td>0015000000MxwHWAAZ</td><td>NA</td><td>Large Enterprise</td><td>Technology</td></tr><tr><td>0015000000MyWMeAAN</td><td>EMEA</td><td>Large Enterprise</td><td>Telco</td></tr><tr><td>0015000000Myg0lAAB</td><td>NA</td><td>Large Enterprise</td><td>Financial Services</td></tr><tr><td>0015000000Mz1pIAAR</td><td>APAC</td><td>Mid-Market</td><td>Financial Services</td></tr><tr><td>0015000000NHWB0AAP</td><td>NA</td><td>Government</td><td>Government</td></tr><tr><td>0015000000NHymBAAT</td><td>NA</td><td>Mid-Market</td><td>Other</td></tr><tr><td>0015000000NI7sRAAT</td><td>NA</td><td>Mid-Market</td><td>Financial Services</td></tr><tr><td>0015000000NI0DpAAL</td><td>NA</td><td>Large Enterprise</td><td>Utilities/Transport</td></tr><tr><td>0015000000NI3qjAAD</td><td>NA</td><td>Large Enterprise</td><td>Technology</td></tr><tr><td>0015000000NKFflAAH</td><td>LATAM</td><td>Government</td><td>Government</td></tr><tr><td>0015000000NjuC0AAJ</td><td>EMEA</td><td>Large Enterprise</td><td>Telco</td></tr><tr><td>0015000000NlVDZAA3</td><td>NA</td><td>Small and Medium Business</td><td>Technology</td></tr><tr><td>0015000000Nm57EAAR</td><td>NA</td><td>Small and Medium Business</td><td>Financial Services</td></tr><tr><td>0015000000NmOHCAA3</td><td>NA</td><td>Large Enterprise</td><td>Financial Services</td></tr><tr><td>0015000000NmiObAAJ</td><td>APAC</td><td>Large Enterprise</td><td>Retail</td></tr><tr><td>0015000000OGOZdAAP</td><td>NA</td><td>Government</td><td>Healthcare</td></tr><tr><td>0015000000OUbVyAAL</td><td>LATAM</td><td>Large Enterprise</td><td>Financial Services</td></tr><tr><td>0015000000OUuCUAA1</td><td>EMEA</td><td>Large Enterprise</td><td>Financial Services</td></tr><tr><td>0015000000OVl9DAAT</td><td>APAC</td><td>Large Enterprise</td><td>Technology</td></tr><tr><td>0015000000Ov859AAB</td><td>LATAM</td><td>Large Enterprise</td><td>Retail</td></tr><tr><td>0015000000OvTF2AAN</td><td>APAC</td><td>Mid-Market</td><td>Financial Services</td></tr><tr><td>0015000000PGDgHAAX</td><td>APAC</td><td>Large Enterprise</td><td>Financial Services</td></tr><tr><td>0015000000PGmuMAAT</td><td>JAPAN</td><td>Large Enterprise</td><td>Other</td></tr><tr><td>00100000001UPeEAAW</td><td>EMEA</td><td>Large Enterprise</td><td>Financial Services</td></tr><tr><td>00100000001Uf7SAAS</td><td>APAC</td><td>Large Enterprise</td><td>Telco</td></tr><tr><td>00100000001ixETAAY</td><td>LATAM</td><td>Mid-Market</td><td>Telco</td></tr><tr><td>0015000000OERI5AAP</td><td>NA</td><td>Mid-Market</td><td>Telco</td></tr><tr><td>0015000000OGUftAAH</td><td>EMEA</td><td>Large Enterprise</td><td>Utilities/Transport</td></tr><tr><td>0015000000OvAzIAAV</td><td>EMEA</td><td>Large Enterprise</td><td>Utilities/Transport</td></tr><tr><td>0015000000OvL2FAAV</td><td>APAC</td><td>Government</td><td>Government</td></tr><tr><td>0015000000OwSkbAAF</td><td>APAC</td><td>Large Enterprise</td><td>Technology</td></tr><tr><td>0015000000PGDN3AAP</td><td>APAC</td><td>Small and Medium Business</td><td>Utilities/Transport</td></tr><tr><td>00100000001jZ9iAAE</td><td>APAC</td><td>Large Enterprise</td><td>Utilities/Transport</td></tr><tr><td>00100000001jZDlAAM</td><td>EMEA</td><td>Large Enterprise</td><td>Manufacturing</td></tr><tr><td>00150000013W26qAAC</td><td>APAC</td><td>Mid-Market</td><td>Technology</td></tr><tr><td>0011T00002aKgRuQAK</td><td>APAC</td><td>Small and Medium Business</td><td>Other</td></tr><tr><td>0015000000MHLrkAAH</td><td>NA</td><td>Government</t ...

# %%
base_labels = base_df.select('theater').distinct().crossJoin(base_df.select('market_segment').distinct()).crossJoin(base_df.select('industry_grouping').distinct()).withColumn('group_label', F.monotonically_increasing_id())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
base_df_labeled = base_df.join(base_labels, how='inner', on=['theater', 'market_segment', 'industry_grouping'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
base_df_labeled.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>theater</th><th>market_segment</th><th>industry_grouping</th><th>id</th><th>group_label</th></tr></thead><tbody><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000ScnjLAAR</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000bPwNoAAK</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000PGmw0AAD</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C67QAF</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000PGnN6AAL</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000eWXGlAAO</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002J3BuiQAF</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8EZpQAN</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oWKoNAAW</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C5AQAV</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000PGnTVAA1</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C6OQAV</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C5QQAV</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C5CQAV</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oWKpQAAW</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8ISpQAN</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000cbsq2AAA</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000PGnErAAL</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oWB7MAAW</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000flepKAAQ</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000bS6JSAA0</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8IStQAN</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8EY1QAN</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oWB3oAAG</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>00150000018ZlP1AAK</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000dZOcwAAG</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>00150000014FW5cAAG</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000001Db6JHAAZ</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>00150000010XEp0AAG</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000wJZvYAAW</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000s3pkIAAQ</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000rmkr6AAA</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000ot2fKAAQ</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oW5qlAAC</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oVWeGAAW</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000bPwQYAA0</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000YlyKyAAJ</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000QQdG2AAL</td><td>0</td></tr><tr><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000Ps4ffAAB</td>< ...

# %%
base_df_labeled.select(F.max('group_label')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------+
# max(group_label)|
# +----------------+
#              389|
# +----------------+
#
# </div>

# %%
base_ratings_by_group = base_recs.join(base_df_labeled.select('id', 'group_label'), on=base_recs.account_id == base_df_labeled.id, how='right').drop('account_id').groupBy('group_label','product_group_line_type_subtype_platform').sum('rating').withColumnRenamed("sum(rating)", 'sum_rating')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
windowSpec = Window.partitionBy('group_label').orderBy(F.desc('sum_rating'))
ranked_recs = base_ratings_by_group.withColumn("ranking", F.dense_rank().over(windowSpec))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
recs_cold_all = ranked_recs.join(base_df_labeled, how='inner', on=['group_label']).dropDuplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
recs_cold_all.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>group_label</th><th>product_group_line_type_subtype_platform</th><th>sum_rating</th><th>ranking</th><th>theater</th><th>market_segment</th><th>industry_grouping</th><th>id</th></tr></thead><tbody><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000ScnjLAAR</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000bPwNoAAK</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000PGmw0AAD</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C67QAF</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000PGnN6AAL</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000eWXGlAAO</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002J3BuiQAF</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8EZpQAN</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oWKoNAAW</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C5AQAV</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000PGnTVAA1</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C6OQAV</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C5QQAV</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8C5CQAV</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oWKpQAAW</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0011T00002U8ISpQAN</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000cbsq2AAA</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000PGnErAAL</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000oWB7MAAW</td></tr><tr><td>0</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>29.977031841874123</td><td>1</td><td>JAPAN</td><td>Government</td><td>Education</td><td>0015000000flepKAAQ</td></tr><tr><td>0</td><td>BIG-IP  ...

# %%
base_recs.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>account_id</th><th>product_group_line_type_subtype_platform</th><th>rating</th></tr></thead><tbody><tr><td>00100000000ujiRAAQ</td><td>NGINX-NGINX Plus-Subscription-Virtual Edition-Virtual</td><td>0.264072060585022</td></tr><tr><td>00100000000ujiRAAQ</td><td>BIG-IP - App Delivery-LTM-Hardware-NA-NA</td><td>0.24919277429580688</td></tr><tr><td>00100000000ujiRAAQ</td><td>Silverline-WAF-Subscription-WAF-NA</td><td>0.23744910955429077</td></tr><tr><td>00100000000ujiRAAQ</td><td>Silverline-IPI-Subscription-IPI-NA</td><td>0.22715792059898376</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-NGINX Plus-Subscription-Virtual Edition-NA</td><td>0.21030524373054504</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-NGINX Plus-Subscription-Virtual Edition-</td><td>0.2095114141702652</td></tr><tr><td>00100000000ujiRAAQ</td><td>BIG-IP - App Delivery-ManOVA-Software-Virtual Edition-NA</td><td>0.19990316033363342</td></tr><tr><td>00100000000ujiRAAQ</td><td>BIG-IP - App Delivery-LTM-Hardware-Appliance-i2600</td><td>0.18692511320114136</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-App Protect-Subscription-Virtual Edition-Virtual</td><td>0.1774865835905075</td></tr><tr><td>00100000000ujiRAAQ</td><td>BIG-IP - Security-IPI-Subscription-NA-NA</td><td>0.1762290745973587</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-App Protect-Subscription-Virtual Edition-NA</td><td>0.1710917353630066</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-App Protect-Subscription-Virtual Edition-</td><td>0.17101263999938965</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Controller-Utility-NA-</td><td>0.16852913796901703</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Instance Manager-Subscription-Virtual Edition-Virtual</td><td>0.15045246481895447</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Microservices-Subscription-Virtual Edition-Virtual</td><td>0.15022030472755432</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Instance Manager-Subscription-Virtual Edition-NA</td><td>0.14857269823551178</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Microservices-Subscription-Virtual Edition-</td><td>0.14787112176418304</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Microservices-Subscription-Virtual Edition-NA</td><td>0.14709967374801636</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>0.14651760458946228</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Controller-Subscription-Virtual Edition-Virtual</td><td>0.14209909737110138</td></tr><tr><td>00100000000ujiRAAQ</td><td>Aspen Mesh-Aspen Mesh-Subscription-Virtual Edition-NA</td><td>0.14042697846889496</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Controller-Subscription-Virtual Edition-NA</td><td>0.12841247022151947</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Controller-Subscription-Virtual Edition-</td><td>0.12819015979766846</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-App Protect-Utility-Marketplace-Virtual</td><td>0.12055769562721252</td></tr><tr><td>00100000000ujiRAAQ</td><td>Aspen Mesh-Aspen Mesh-Software-Virtual Edition-NA</td><td>0.11680449545383453</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-Microservices-Utility-Marketplace-Virtual</td><td>0.10942983627319336</td></tr><tr><td>00100000000ujiRAAQ</td><td>NGINX-LTM-Subscription-Virtual Edition-Virtual</td><td>0.10897281765937805</td></tr><tr><td>00100000000ujiRAAQ</td><td>BIG-IP - App Delivery-LTM-Hardware-Blade-B2250</td><td>0.10848721861839294</td></tr><tr><td>00100000000ujiRAAQ</td><td>BIG-IP - Security-IAM-Subscription-Virtual Edition-Virtual</td><td>0.09818580746650696</td></tr><tr><td>00100000000ujiRAAQ</td><td>BIG-IP - App Delivery-LTM-Hardware-Chassis-C2400</td><td>0.09474063664674759</td></tr><tr><td>00100000000ujiUAAQ</td><td>NGINX-NGINX Plus-Subscription-Virtual Edition-Virtual</td><td>0.7397838830947876</td></tr><tr><td>00100000000ujiUAAQ</td><td>BIG-IP  ...

# %%
base_recs = base_recs.withColumn('is_cold_case', F.lit(0))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cold_case_recs = recs_cold_all.withColumnRenamed('id', 'account_id').join(base_recs, on=['account_id'], how='leftanti')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cold_case_recs.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>account_id</th><th>group_label</th><th>product_group_line_type_subtype_platform</th><th>sum_rating</th><th>ranking</th><th>theater</th><th>market_segment</th><th>industry_grouping</th></tr></thead><tbody><tr><td>0015000000MHL30AAH</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000VBKqWAAX</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>00130000002aQSqAAM</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000oD49NAAS</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000aFRJHAA4</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000001M4n0QAAR</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000cZR9hAAG</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000ov2khAAA</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000RiDCYAA3</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000001HbPYXAA3</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000cZ7cRAAS</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000001OxnwaAAB</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000001KzJsKAAV</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000001FEruWAAT</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>00130000006faLdAAI</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>00130000006obLCAAY</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000TWHeXAAX</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>00150000015GSKWAA4</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000I7KOIAA3</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td><td>Education</td></tr><tr><td>0015000000FZ4hQAAT</td><td>1</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>19</td><td>NA</td><td>Government</td> ...

# %%
full_recs = cold_case_recs.select('account_id', 'product_group_line_type_subtype_platform', 'sum_rating').withColumnRenamed('sum_rating', 'rating').withColumn('is_cold_case', F.lit(1)).union(base_recs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
full_recs.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>account_id</th><th>product_group_line_type_subtype_platform</th><th>rating</th><th>is_cold_case</th></tr></thead><tbody><tr><td>0015000000ajJf5AAE</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000001TPtT9AAL</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000aj5bbAAA</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0013000000Ddg7UAAR</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000LlT3GAAV</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000lSrJjAAK</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000Ri9dlAAB</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>00130000009DplHAAS</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>00150000016CvZ0AAK</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000R9lxxAAB</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000001TQryJAAT</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000u4w7PAAQ</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0011T00002J3CKzQAN</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000001M3aEVAAZ</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000aff1TAAQ</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000yLWhdAAG</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000JL3huAAD</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>00100000000ulzsAAA</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000K0k1FAAR</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000WWywHAAT</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000TUtkvAAD</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000ouw0IAAQ</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000owSJhAAM</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0011T00002KBID9QAP</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000n8z3kAAA</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000KgHCgAAN</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000T4tO1AAJ</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000OYCMqAAP</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000TVUR1AAP</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417< ...

# %% [markdown]
# NOTE that:
# * the ratings from the above dataframe (full_recs) is based on staking the ratings from cold_case recs and that from raw_recs
# * However, the cold case recs rating is obtained by summing the ratings of individual products within each group

# %%
full_recs.filter(full_recs.account_id=='0015000000QsIwqAAF').orderBy(F.desc('rating')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>account_id</th><th>product_group_line_type_subtype_platform</th><th>rating</th><th>is_cold_case</th></tr></thead><tbody><tr><td>0015000000QsIwqAAF</td><td>NGINX-NGINX Plus-Subscription-Virtual Edition-Virtual</td><td>286.10006020218134</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>BIG-IP - App Delivery-LTM-Hardware-NA-NA</td><td>276.0566476136446</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>Silverline-WAF-Subscription-WAF-NA</td><td>271.8257345855236</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>Silverline-IPI-Subscription-IPI-NA</td><td>256.4736870005727</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-NGINX Plus-Subscription-Virtual Edition-NA</td><td>231.33696269989014</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-NGINX Plus-Subscription-Virtual Edition-</td><td>230.6715698763728</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>BIG-IP - App Delivery-LTM-Hardware-Appliance-i2600</td><td>216.10008216649294</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>BIG-IP - App Delivery-ManOVA-Software-Virtual Edition-NA</td><td>206.53556118905544</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-App Protect-Subscription-Virtual Edition-Virtual</td><td>194.21774620562792</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>BIG-IP - Security-IPI-Subscription-NA-NA</td><td>190.99843026697636</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-App Protect-Subscription-Virtual Edition-NA</td><td>187.5264317691326</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-App Protect-Subscription-Virtual Edition-</td><td>187.02696858346462</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Controller-Utility-NA-</td><td>185.26241750270128</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Microservices-Subscription-Virtual Edition-Virtual</td><td>163.83937162905931</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Instance Manager-Subscription-Virtual Edition-Virtual</td><td>162.71580823510885</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Instance Manager-Subscription-Virtual Edition-NA</td><td>161.08521853387356</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Microservices-Subscription-Virtual Edition-</td><td>159.76939541101456</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Microservices-Subscription-Virtual Edition-NA</td><td>159.56129923462868</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-NGINX Plus-Utility-Marketplace-Virtual</td><td>159.55134350061417</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Controller-Subscription-Virtual Edition-Virtual</td><td>156.32313598692417</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>Aspen Mesh-Aspen Mesh-Subscription-Virtual Edition-NA</td><td>150.04380850493908</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Controller-Subscription-Virtual Edition-NA</td><td>138.28410360217094</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Controller-Subscription-Virtual Edition-</td><td>137.22780060768127</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-App Protect-Utility-Marketplace-Virtual</td><td>126.71309173107147</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>Aspen Mesh-Aspen Mesh-Software-Virtual Edition-NA</td><td>119.55579002201557</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-Microservices-Utility-Marketplace-Virtual</td><td>112.41501197218895</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>NGINX-LTM-Subscription-Virtual Edition-Virtual</td><td>110.87793702632189</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>BIG-IP - App Delivery-LTM-Software-Virtual Edition-NA</td><td>109.87645453214645</td><td>1</td></tr><tr><td>0015000000QsIwqAAF</td><td>BIG-IP - Security-IAM-Software-Add-on-NA</td><td>106.04807642102242</td><td>1</td></tr><tr><td>00150000 ...
